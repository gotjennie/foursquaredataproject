# %%
import os
import json
import math
import time
import cPickle as pickle
import multiprocessing as mp

import reverse_geocoder as rg
import pandas as pd
import numpy as np
import fiona
import shapely.geometry

# %% [markdown]
# ## Read in data

# %%
def read_data(directory, file_name, header_names, columns_types):
    """
    Check to see if csv file exists, if not read in and parse dat file
    
    Inputs:
        directory (string): directory where data is stored
        file_name (string): file name WITHOUT extension
        header_names (list of strings): list of strings representing names for each column
        column_types (dict of numpy dtype objects): dict of column types. used to typecast columns. keys must be in header_names
        
    Output:
        (pandas dataframe): dataframe with formatted columns 
    """
    if os.path.isfile(directory + file_name + '.pickle'):
        print 'Reading pickled pandas DF: ' + directory + file_name + '.pickle'
        
        # read in pickled data frame 
        with open(directory + file_name + '.pickle', 'rb') as input_file:
            raw_data_df = pickle.load(input_file)
    else:
        print 'Reading raw txt file: ' + directory + file_name + '.txt'
        
        # read in file and format columns
        raw_data_df = pd.read_table(directory + file_name + '.txt', \
                                    names=header_names, \
                                    engine='c')
        
        for k in columns_types:
            v = columns_types[k]
            raw_data_df[k] = raw_data_df[k].astype(v)
        
    # return data
    return raw_data_df

# %%
# read in each data frame
checkin_df = read_data('./raw_data/', 
                       'dataset_TIST2015_Checkins', 
                       ['user_id', 'venue_id', 'utc_time', 'timezone_offset'],
                       {'user_id': np.str, 'venue_id': np.str, 'utc_time': np.str, 'timezone_offset': np.int64})

cities_df = read_data('./raw_data/', 
                      'dataset_TIST2015_Cities', 
                      ['city_name', 'latitude', 'longitude', 'country_code', 'country_name', 'city_type'],
                      {'city_name': np.str, 'latitude': np.float, 'longitude': np.float, 'country_code': np.str, 'country_name': np.str, 'city_type': np.str})

venues_df = read_data('./raw_data/', 
                      'dataset_TIST2015_POIs', 
                      ['venue_id', 'latitude', 'longitude', 'venue_category', 'country_code'],
                      {'venue_id': np.str, 'latitude': np.float, 'longitude': np.float, 'venue_category': np.str, 'country_code': np.str})
# Out:
# Reading raw txt file: ./raw_data/dataset_TIST2015_Checkins.txt
# Reading raw txt file: ./raw_data/dataset_TIST2015_Cities.txt
# Reading raw txt file: ./raw_data/dataset_TIST2015_POIs.txt

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Select venues in US only

# %%
# assign cities and countries
current_reverse_geocode = rg.search(zip(venues_df['latitude'], venues_df['longitude']))
cities = [x['name'] for x in current_reverse_geocode]
states = [x['admin1'] for x in current_reverse_geocode]
countries = [x['cc'] for x in current_reverse_geocode]

venues_df['city'] = cities
venues_df['state'] = states
venues_df['country'] = countries
# Out:
# Loading formatted geocoded file...

# %%
# select venues where country are in US
venues_df = venues_df[venues_df['country'] == 'US']

# select cities where country is US
cities_df = cities_df[cities_df['country_code'] == 'US']

# select checkins that are only for venues in US 
checkin_df = checkin_df[checkin_df['venue_id'].isin(venues_df['venue_id'])]

# %%
checkin_by_user = checkin_df[['user_id', 'venue_id']].merge(venues_df[['venue_id', 'venue_category', 'latitude', 'longitude','city', 'state', 'country']], \
                                                            on='venue_id',
                                                            how='left').reset_index()

# %% [markdown]
# ### Select only Chicago, San Francisco, and Manhattan for city since those are what we will focus on for neighborhoods

# %%
checkin_by_user = checkin_by_user[checkin_by_user['city'].isin(['Chicago', 'San Francisco', 'Manhattan'])]

# %%
checkin_by_user
# Out:
#            index user_id                  venue_id  \
# 84           Manhattan    New York      US
# 85           Manhattan    New York      US
# 88       San Francisco  California      US
# 130            Chicago    Illinois      US
# 136      San Francisco  California      US
# 139            Chicago    Illinois      US
# 141            Chicago    Illinois      US
# 146            Chicago    Illinois      US
# 156      San Francisco  California      US
# 168            Chicago    Illinois      US
# 197      San Francisco  California      US
# 213          Manhattan    New York      US
# 220            Chicago    Illinois      US
# 261      San Francisco  California      US
# 268          Manhattan    New York      US
# 325      San Francisco  California      US
# 343          Manhattan    New York      US
# 351          Manhattan    New York      US
# 380      San Francisco  California      US
# 388      San Francisco  California      US
# 392          Manhattan    New York      US
# 394            Chicago    Illinois      US
# 411            Chicago    Illinois      US
# ...                ...         ...     ...
# 3559949      Manhattan    New York      US
# 3559954      Manhattan    New York      US
# 3559959        Chicago    Illinois      US
# 3559965        Chicago    Illinois      US
# 3559983      Manhattan    New York      US
# 3559988      Manhattan    New York      US
# 3560031        Chicago    Illinois      US
# 3560036      Manhattan    New York      US
# 3560037      Manhattan    New York      US
# 3560048        Chicago    Illinois      US
# 3560050      Manhattan    New York      US
# 3560054        Chicago    Illinois      US
# 3560078      Manhattan    New York      US
# 3560085        Chicago    Illinois      US
# 3560100  San Francisco  California      US
# 3560103      Manhattan    New York      US
# 3560106        Chicago    Illinois      US
# 3560113      Manhattan    New York      US
# 3560135      Manhattan    New York      US
# 3560152      Manhattan    New York      US
# 3560161      Manhattan    New York      US
# 3560177  San Francisco  California      US
# 3560220      Manhattan    New York      US
# 3560223      Manhattan    New York      US
# 3560224        Chicago    Illinois      US
# 3560233        Chicago    Illinois      US
# 3560238      Manhattan    New York      US
# 3560240        Chicago    Illinois      US
# 3560249      Manhattan    New York      US
# 3560264        Chicago    Illinois      US
#
# [305524 rows x 9 columns]

# %% [markdown]
# ## Get neighborhoods for each checkin

# %% [markdown]
# ### Create shape arrays from neighborhood shape data

# %%
ca_collection = fiona.open('./shape_files/ZillowNeighborhoods-CA.shx')
il_collection = fiona.open('./shape_files/ZillowNeighborhoods-il.shx')
ny_collection = fiona.open('./shape_files/ZillowNeighborhoods-ny.shx')

# %%
ca_shapes = [(shapefile_record['properties']['Name'], shapely.geometry.asShape(shapefile_record['geometry'])) for shapefile_record in ca_collection]
il_shapes = [(shapefile_record['properties']['Name'], shapely.geometry.asShape(shapefile_record['geometry'])) for shapefile_record in il_collection]
ny_shapes = [(shapefile_record['properties']['Name'], shapely.geometry.asShape(shapefile_record['geometry'])) for shapefile_record in ny_collection]

# %% [markdown]
# ### Find neighborhood in parallel

# %%
def get_neighborhood(row):
    """
    Uses shape files to get neighborhood of current row
    
    Inputs:
        row (tuple of 3 elements): contains (lat, long, city) where lat, long are float and city is string
        
    Output:
        (string): neighborhood name or None
    """
    latitude = row[0]
    longitude = row[1]
    city = row[2]
    
    # create point
    point = shapely.geometry.Point(longitude, latitude) # longitude, latitude
    
    # figure out what shapefile to use
    curr_shapefile = None
    if city == 'Chicago':
        curr_shapefile = il_shapes
    elif city == 'San Francisco':
        curr_shapefile = ca_shapes
    elif city == 'Manhattan':
        curr_shapefile = ny_shapes
    else:
        return None
    
    # find neighborhood
    for shape in curr_shapefile:
        if point.within(shape[1]):
            return shape[0]
    
    # if not found, return None
    return None

# %%
# format data for input
data = zip(checkin_by_user['latitude'], checkin_by_user['longitude'], checkin_by_user['city'])

# run code in parallel
t0 = time.time()
N_CORES = mp.cpu_count()
pool = mp.Pool(N_CORES)
r = pool.map(get_neighborhood, data)
t1 = time.time()

# time code
print str(t1 - t0) + ' seconds for ' + str(len(data)) + ' rows'
# Out:
# 26020.8534 seconds for 305524 rows

# %%
checkin_by_user['neighborhood'] = r
checkin_by_user
# Out:
#            index user_id                  venue_id  \
# 4              4  163570  4b2277b1f964a5203f4724e3
# 8              8   44228  4a95f126f964a520952520e3
# 25            25  144940  4ec6e5e55c5ce271bce067fc
# 40            40  198359  49edce76f964a520f9671fe3
# 47            47  139980  45840a3af964a520903f1fe3
# 68            68  201081  4de0117c45dd3eae8764d6ac
# 69            69   71374  49c1ee05f964a520e0551fe3
# 84            84  132121  4d0cc47f903d37041864bf55
# 85            85  139985  4297b480f964a52062241fe3
# 88            88  116934  4f7b2078e4b0d859b691c07b
# 130          130  106158  4efd482c9adffb90ca930cb1
# 136          136  122232  461937cff964a5205c451fe3
# 139          139  251458  49bac1c8f964a520a0531fe3
# 141          141   94652  4b8043c3f964a5204f6230e3
# 146          146   91831  4b7087c7f964a52020202de3
# 156          156   31494  4b7f3359f964a520a01e30e3
# 168          168   41570  4b32ad2cf964a520a11125e3
# 197          197  144942  42bf4180f964a520b1251fe3
# 213          213   47124  4a689777f964a520a0ca1fe3
# 220          220    2680  4a823e8af964a520fcf81fe3
# 261          261  195770  4f7b115ee4b02f1b2cffd486
# 268          268   21011  4bc308db4cdfc9b639bf9621
# 325          325  215037  437e6b00f964a520b72a1fe3
# 343          343  217977  4b560838f964a520d5fc27e3
# 351          351    7381  4ad607d3f964a520a10421e3
# 380          380   93669  4db4b3894b226b343d92deb4
# 388          388  176400  4ad91f15f964a5204c1821e3
# 392          392   54351  4b7718d4f964a520077d2ee3
# 394          394   44228  4a881bc2f964a5202d0520e3
# 411          411   44228  4bbf93712a89ef3bd329ef88
# ...          ...     ...                       ...
# 3559949  3559949    8115  4b05f2bcf964a52063e622e3
# 3559954  3559954  231594  3fd66200f964a520b0e71ee3
# 3559959  3559959   16435  4a077bbbf964a52060731fe3
# 3559965  3559965  106436  4a622a61f964a5203dc31fe3
# 3559983  3559983   76902  49c58285f964a5200a571fe3
# 3559988  3559988   88019  48970b66f964a52075511fe3
# 3560031  3560031  240259  4d35acc9306160fc05226c88
# 3560036  3560036   45119  4eeca38f9adf257d65d19276
# 3560037  3560037   47966  4ab172a4f964a520816920e3
# 3560048  3560048  112590  4b54f453f964a52008d527e3
# 3560050  3560050    6591  4a97e23df964a520db2920e3
# 3560054  3560054   67386  4c4b6330d2bf76b09bead384
# 3560078  3560078   28856  4b135e9bf964a520ad9623e3
# 3560085  3560085  239127  4ee80effa69d4c7d8788954a
# 3560100  3560100    4070  45073758f964a52021391fe3
# 3560103  3560103   87330  4aaf803ef964a520376420e3
# 3560106  3560106   95917  4a4e8b00f964a520a5ae1fe3
# 3560113  3560113   87330  4e863b32f790e3cd5056eff1
# 3560135  3560135   87330  4c8e5e5e1664b1f784d39f2f
# 3560152  3560152  108901  3fd66200f964a520bee71ee3
# 3560233                               Pet Service  41.906718  -87.650260
# 3560238                                   Theater  40.809684  -73.950176
# 3560240                                       Gym  41.878161  -87.638862
# 3560249                 Latin American Restaurant  40.764217  -73.988321
# 3560264                                Steakhouse  41.880649  -87.653954
#
#                   city       state country                       neighborhood
# 4              Chicago    Illinois      US                           The Loop
# 8              Chicago    Illinois      US  University Village - Little Italy
# 25       San Francisco  California      US            Van Ness - Civic Center
# 40           Manhattan    New York      US                            Midtown
# 47             Chicago    Illinois      US                       Lincoln Park
# 68       San Francisco  California      US                        Yerba Buena
# 69       San Francisco  California      US                        Yerba Buena
# 84           Manhattan    New York      US                    Upper East Side
# 85           Manhattan    New York      US                    Upper West Side
# 88       San Francisco  California      US                    South of Market
# 130            Chicago    Illinois      US                        River North
# 136      San Francisco  California      US                    North Panhandle
# 139            Chicago    Illinois      US                         South Loop
# 141            Chicago    Illinois      US                         South Loop
# 146            Chicago    Illinois      US  University Village - Little Italy
# 156      San Francisco  California      US                           Downtown
# 168            Chicago    Illinois      US                        River North
# 197      San Francisco  California      US                           Downtown
# 213          Manhattan    New York      US                            Midtown
# 220            Chicago    Illinois      US                Sheffield Neighbors
# 261      San Francisco  California      US                 Financial District
# 268          Manhattan    New York      US                    Upper West Side
# 325      San Francisco  California      US                       Russian Hill
# 343          Manhattan    New York      US                            Midtown
# 351          Manhattan    New York      US                    Upper East Side
# 380      San Francisco  California      US                   Buena Vista Park
# 388      San Francisco  California      US                   North Waterfront
# 392          Manhattan    New York      US                    Upper East Side
# 394            Chicago    Illinois      US                         Near North
# 411            Chicago    Illinois      US                      Streeterville
# ...                ...         ...     ...                                ...
# 3559949      Manhattan    New York      US                        East Harlem
# 3559954      Manhattan    New York      US                            Midtown
# 3559959        Chicago    Illinois      US                         Near North
# 3559965        Chicago    Illinois      US                           The Loop
# 3559983      Manhattan    New York      US                    Columbus Circle
# 3559988      Manhattan    New York      US                            Clinton
# 3560031        Chicago    Illinois      US                           Bucktown
# 3560036      Manhattan    New York      US                    Columbus Circle
# 3560037      Manhattan    New York      US                   Garment District
# 3560048        Chicago    Illinois      US                           The Loop
# 3560050      Manhattan    New York      US                    Upper East Side
# 3560054        Chicago    Illinois      US                       Noble Square
# 3560078      Manhattan    New York      US                            Midtown
# 3560085        Chicago    Illinois      US                         South Loop
# 3560100  San Francisco  California      US                    South of Market
# 3560103      Manhattan    New York      US                               None
# 3560106        Chicago    Illinois      US                      Streeterville
# 3560113      Manhattan    New York      US               Randals-Wards Island
# 3560135      Manhattan    New York      US                         Mott Haven
# 3560152      Manhattan    New York      US                    Columbus Circle
# 3560161      Manhattan    New York      US                   Garment District
# 3560177  San Francisco  California      US                            Mission
# 3560220      Manhattan    New York      US                    Upper West Side
# 3560223      Manhattan    New York      US                    Upper East Side
# 3560224        Chicago    Illinois      US                         Near North
# 3560233        Chicago    Illinois      US                       Goose Island
# 3560238      Manhattan    New York      US                             Harlem
# 3560240        Chicago    Illinois      US                     West Loop Gate
# 3560249      Manhattan    New York      US                    Columbus Circle
# 3560264        Chicago    Illinois      US                     Near West Side
#
# [305524 rows x 10 columns]

# %%
checkin_by_user.to_csv('./processed_data/checking-with-neighborhoods.csv', index=False)
