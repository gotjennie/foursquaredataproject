# %% [markdown]
# ## Imports and common functions

# %%
import os
import json
import cPickle as pickle

# analysis
import pandas as pd
import numpy as np
import reverse_geocoder as rg

# plotting
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load in data
# Using a mini dataset bc my computer is weak

# %%
def read_data(directory, file_name, header_names, columns_types):
    """
    Check to see if csv file exists, if not read in and parse dat file
    
    Inputs:
        directory (string): directory where data is stored
        file_name (string): file name WITHOUT extension
        header_names (list of strings): list of strings representing names for each column
        column_types (dict of numpy dtype objects): dict of column types. used to typecast columns. keys must be in header_names
        
    Output:
        (pandas dataframe): dataframe with formatted columns 
    """
    if os.path.isfile(directory + file_name + '.pickle'):
        print 'Reading pickled pandas DF: ' + directory + file_name + '.pickle'
        
        # read in pickled data frame 
        with open(directory + file_name + '.pickle', 'rb') as input_file:
            raw_data_df = pickle.load(input_file)
    else:
        print 'Reading raw txt file: ' + directory + file_name + '.txt'
        
        # read in file and format columns
        raw_data_df = pd.read_table(directory + file_name + '.txt', \
                                    names=header_names, \
                                    engine='c')
        raw_data_df = raw_data_df.astype(columns_types)
        
        # export file as pickled object
        with open(directory + file_name + '.pickle', 'wb') as output_file:
            pickle.dump(raw_data_df, output_file, pickle.HIGHEST_PROTOCOL)
        
    # return data
    return raw_data_df

# %%
# read in each data frame
checkin_df = read_data('./raw_data/', 
                       'jennie_full', 
                       ['user_id', 'venue_id', 'utc_time', 'timezone_offset'],
                       {'user_id': np.str, 'venue_id': np.str, 'utc_time': np.str, 'timezone_offset': np.int64})
# Out:
# Reading pickled pandas DF: ./raw_data/jennie_full.pickle

# %% [markdown]
# ## Data Cleaning

# %%
checkin_df
# Out:
#            index user_id                  venue_id  \
# 0              0  221021  4a85b1b3f964a520eefe1fe3
# 1              1   66981  4b4606f2f964a520751426e3
# 2              2   28761  4b4bade2f964a520cfa326e3
# 3              3   39350  49bbd6c0f964a520f4531fe3
# 4              4  163570  4b2277b1f964a5203f4724e3
# 5              5    1702  4bbf31c9f353d13a942b7e10
# 6              6   84752  4b749db3f964a520f9e72de3
# 7              7   91828  4c029902310fc9b6e2a7c461
# 8              8   44228  4a95f126f964a520952520e3
# 9              9   32655  4a43c0aef964a520c6a61fe3
# 10            10  159575  4f709643e4b08a0bbcf3237c
# 11            11  180958  4b5b6004f964a520e1f828e3
# 12            12  113200  4addf08af964a520856621e3
# 13            13   44229  4c53ac4bfd2ea5932cbed228
# 14            14   61794  4d6bd1e471d3721ed2489606
# 15            15   49932  4b1d4b75f964a520560e24e3
# 16            16   32886  4c868360d34ca1437d8e5080
# 17            17    1090  4be31c9721d5a5932b391811
# 18            18   44231  4ac010f4f964a520a79320e3
# 19            19  237199  4b69a522f964a52010ab2be3
# 20            20    5445  439ec330f964a520102c1fe3
# 21            21   31493  4b3e8ac2f964a520b79e25e3
# 22            22  143277  4baadf5df964a520738b3ae3
# 23            23   11959  4b70040ff964a52080032de3
# 24            24  129266  4b50b839f964a5203e2f27e3
# 25            25  144940  4ec6e5e55c5ce271bce067fc
# 26            26   79158  4f6f982ae4b0463c95b58a39
# ...                          ...               ...     ...
# 3560239                St. Louis          Missouri      US
# 3560240                  Chicago          Illinois      US
# 3560241              Chula Vista        California      US
# 3560242                  Burbank        California      US
# 3560243                 Lakewood         Tennessee      US
# 3560244                San Diego        California      US
# 3560245                    Lyons          Illinois      US
# 3560246                 Columbus              Ohio      US
# 3560247                  Atlanta           Georgia      US
# 3560248         Richmond Heights          Missouri      US
# 3560249                Manhattan          New York      US
# 3560250                 Berkeley        California      US
# 3560251         Washington, D.C.  Washington, D.C.      US
# 3560252                Charlotte    North Carolina      US
# 3560253         Washington, D.C.  Washington, D.C.      US
# 3560254                  Burbank        California      US
# 3560255                Milwaukee         Wisconsin      US
# 3560256         Long Island City          New York      US
# 3560257                   Tucker           Georgia      US
# 3560258                   Warren          Michigan      US
# 3560259        North Druid Hills           Georgia      US
# 3560260                  Hoboken        New Jersey      US
# 3560261           Lake Magdalene           Florida      US
# 3560262         Washington, D.C.  Washington, D.C.      US
# 3560263         Garfield Heights              Ohio      US
# 3560264                  Chicago          Illinois      US
# 3560265                  Bedford              Ohio      US
# 3560266                  Arbutus          Maryland      US
# 3560267                  Houston             Texas      US
# 3560268            New York City          New York      US
#
# [3560269 rows x 9 columns]

# %%
#['city'].unique()}).reset_index()

venue_categories = checkin_df['venue_category'].unique() 



# unique_cities_df['unique_venues_count'] = unique_cities_df.unique_venues.apply(len)
# unique_cities_df['unique_cities_count'] = unique_cities_df.unique_cities.apply(len)
# unique_cities_df.sort_values(['unique_cities_count'], ascending=[False])

# %%
checkin_df['venue_category']
# Out:
# 0                                   Coffee Shop
# 1                                        Office
# 2                         College Arts Building
# 3                           Arts & Crafts Store
# 4                               Conference Room
# 5                                      Hospital
# 6                                   Coffee Shop
# 7                            Miscellaneous Shop
# 8                                 Train Station
# 9                                        Bridge
# 10                                   Food Truck
# 11                                Spa / Massage
# 12                               Student Center
# 13                                Design Studio
# 14                              Automotive Shop
# 15                             Department Store
# 16                     College Science Building
# 17                             Asian Restaurant
# 18                            Convenience Store
# 19                                 Burger Joint
# 20                                      Airport
# 21                                Grocery Store
# 22                                        Plaza
# 23                            College Cafeteria
# 24                                Grocery Store
# 25                                    City Hall
# 26     Residential Building (Apartment / Condo)
# 27                                          Bar
# 28                                    BBQ Joint
# 29                         Fast Food Restaurant
#                          ...
# 970                                 Coffee Shop
# 971                         American Restaurant
# 972                                    Hospital
# 973                             Automotive Shop
# 974                              Cosmetics Shop
# 975                                        Mall
# 976                                      Office
# 977                              Breakfast Spot
# 978                              Home (private)
# 979                                        Mall
# 980                               Tanning Salon
# 981                                Airport Gate
# 982                                    Hospital
# 983                               Train Station
# 984                                Neighborhood
# 985                          Salon / Barbershop
# 986                                        Caf
# 987                                      Subway
# 988                              Home (private)
# 989                         Japanese Restaurant
# 990                        Fast Food Restaurant
# 991                           College Classroom
# 992                                       Caf
# 993                            Department Store
# 994                                 Golf Course
# 995                              Home (private)
# 996                               Movie Theater
# 997                             Coworking Space
# 998                           College Classroom
# 999                                Burger Joint
# Name: venue_category, Length: 1000, dtype: object

# %%
categories_df = pd.DataFrame(checkin_df.groupby('venue_category').index.nunique()).reset_index()

categories_df.columns = ['venue_category', 'num_checkins']

# %%
categories_df.sort_values(['num_checkins'], ascending=[False])
# Out:
#                                venue_category  num_checkins
# 36                                Coffee Shop            48
# 107                            Home (private)            42
# 140                                    Office            41
# 100                             Grocery Store            27
# 164                            Sandwich Place            25
# 130                        Mexican Restaurant            24
# 24                               Burger Joint            20
# 0                                     Airport            19
# 23                                   Building            19
# 125                                      Mall            18
# 3                         American Restaurant            17
# 146                                      Park            16
# 160                                      Road            15
# 157  Residential Building (Apartment / Condo)            15
# 79                       Fast Food Restaurant            15
# 38                  College Academic Building            14
# 66                           Department Store            14
# 12                                       Bank            14
# 195                                University            12
# 89                       Gas Station / Garage            12
# 13                                        Bar            11
# 9                             Automotive Shop            11
# 150                               Pizza Place            10
# 73                       Drugstore / Pharmacy            10
# 142                      Other Great Outdoors            10
# 111                            Ice Cream Shop            10
# 101                                       Gym             9
# 35                             Clothing Store             9
# 60                            Coworking Space             9
# 163                        Salon / Barbershop             9
# ..                                        ...           ...
# 80                               Fire Station             1
# 116                             Jewelry Store             1
# 113                             Indie Theater             1
# 112                       Indie Movie Theater             1
# 17                              Boat or Ferry             1
# 109                             Hot Dog Joint             1
# 83                                 Food Court             1
# 18                                  Bookstore             1
# 106                              Hockey Arena             1
# 85                           Football Stadium             1
# 20                       Brazilian Restaurant             1
# 127                  Mediterranean Restaurant             1
# 129                               Men's Store             1
# 75                             Emergency Room             1
# 151                                     Plane             1
# 58                             Cosmetics Shop             1
# 161                                 Rock Club             1
# 97                               Gourmet Shop             1
# 158                                    Resort             1
# 61                               Credit Union             1
# 62                           Cuban Restaurant             1
# 91                                    Gay Bar             1
# 132                         Mobile Phone Shop             1
# 149                                      Pier             1
# 144                     Outdoors & Recreation             1
# 141                               Opera House             1
# 14                             Baseball Field             1
# 135                                 Multiplex             1
# 133                       Monument / Landmark             1
# 148                                 Pet Store             1
#
# [204 rows x 2 columns]

# %%
import fiona
import shapely.geometry

# %%
tiny_checkin_sf_df = checkin_df[checkin_df['city']=='San Francisco']
tiny_checkin_chi_df = checkin_df[checkin_df['city']=='Chicago']
tiny_checkin_nyc_df = checkin_df[checkin_df['city']=='Manhattan']

# %%
fiona_collection = fiona.open('./raw_data/ZillowNeighborhoods-CA.shx')
def getNeighborhood(x):
    lat = x[4]
    lon = x[5]
    point = shapely.geometry.Point(lon, lat) # longitude, latitude

    for shapefile_record in fiona_collection:

         # Use Shapely to create the polygon
        shape = shapely.geometry.asShape(shapefile_record['geometry'])

        if point.within(shape):
            try:
                return shapefile_record['properties']['Name']
            except:
                return None
        
tiny_checkin_sf_df['neighborhood'] = tiny_checkin_sf_df.apply(getNeighborhood, axis=1)

# %%
tiny_checkin_sf_df
# Out:
#       index user_id                  venue_id                venue_category  \
# 25       25  144940  4ec6e5e55c5ce271bce067fc                     City Hall
# 213    213   47124  4a689777f964a520a0ca1fe3           Restaurant  40.755275
# 268    268   21011  4bc308db4cdfc9b639bf9621              Dog Run  40.790606
# 343    343  217977  4b560838f964a520d5fc27e3       Sandwich Place  40.759849
# 351    351    7381  4ad607d3f964a520a10421e3                 Bank  40.778252
# 392    392   54351  4b7718d4f964a520077d2ee3  Sporting Goods Shop  40.779014
# 456    456    7381  4ca66eec5a1e952129d98ace       Clothing Store  40.778439
# 487    487   37893  447bf8f1f964a520ec331fe3    Electronics Store  40.763823
#
#      longitude       city     state country     neighborhood
# 40  -73.985778  Manhattan  New York      US          Midtown
# 84  -73.955341  Manhattan  New York      US  Upper East Side
# 85  -73.973203  Manhattan  New York      US  Upper West Side
# 213 -73.978806  Manhattan  New York      US          Midtown
# 268 -73.980521  Manhattan  New York      US  Upper West Side
# 343 -73.972124  Manhattan  New York      US          Midtown
# 351 -73.954629  Manhattan  New York      US  Upper East Side
# 392 -73.954039  Manhattan  New York      US  Upper East Side
# 456 -73.954515  Manhattan  New York      US  Upper East Side
# 487 -73.973010  Manhattan  New York      US          Midtown

# %%
fiona_collection = fiona.open('./raw_data/ZillowNeighborhoods-NY.shx')
        
tiny_checkin_nyc_df['neighborhood'] = tiny_checkin_nyc_df.apply(getNeighborhood, axis=1)

# %%
tiny_checkin_chi_df
# Out:
#      index user_id                  venue_id          venue_category  \
# 4        4  163570  4b2277b1f964a5203f4724e3         Conference Room
# 8        8   44228  4a95f126f964a520952520e3           Train Station
# 47      47  139980  45840a3af964a520903f1fe3                     Zoo
# 130    130  106158  4efd482c9adffb90ca930cb1      Mexican Restaurant
# 139    139  251458  49bac1c8f964a520a0531fe3          Sandwich Place
# 141    141   94652  4b8043c3f964a5204f6230e3  College Residence Hall
# 146    146   91831  4b7087c7f964a52020202de3         College Library
# 168    168   41570  4b32ad2cf964a520a11125e3        Sushi Restaurant
# 220    220    2680  4a823e8af964a520fcf81fe3           Train Station
# 394    394   44228  4a881bc2f964a5202d0520e3                  Subway
#
#       latitude  longitude     city     state country  \
# 4    41.886485 -87.623692  Chicago  Illinois      US
# 8    41.875497 -87.649484  Chicago  Illinois      US
# 47   41.921740 -87.633758  Chicago  Illinois      US
# 130  41.896599 -87.632175  Chicago  Illinois      US
# 139  41.867852 -87.642037  Chicago  Illinois      US
# 141  41.874858 -87.627312  Chicago  Illinois      US
# 146  41.871955 -87.650524  Chicago  Illinois      US
# 168  41.890809 -87.631717  Chicago  Illinois      US
# 220  41.925171 -87.652890  Chicago  Illinois      US
# 394  41.896651 -87.628160  Chicago  Illinois      US
#
#                           neighborhood
# 4                             The Loop
# 8    University Village - Little Italy
# 47                        Lincoln Park
# 130                        River North
# 139                         South Loop
# 141                         South Loop
# 146  University Village - Little Italy
# 168                        River North
# 220                Sheffield Neighbors
# 394                         Near North

# %%
fiona_collection = fiona.open('./raw_data/ZillowNeighborhoods-IL.shx')
        
tiny_checkin_chi_df['neighborhood'] = tiny_checkin_chi_df.apply(getNeighborhood, axis=1)
